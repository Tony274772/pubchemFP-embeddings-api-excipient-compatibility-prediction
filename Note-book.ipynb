# %%
import pandas as pd
df=pd.read_csv("start_dataset.csv")
df[df["Outcome1"]==1].count()
# Out:
# API_CID             344
# Excipient_CID       344
# Outcome1            344
# API_Smiles          344
# Excipient_Smiles    344
# dtype: int64
